# %%
using Plots

# %%
function calc(N, n, ϵ)
    return n * (1-ϵ)^n + (N-n)*ϵ^(N-n)
end
# Out:
# calc (generic function with 1 method)

# %%
N = 100
ϵ = 0.3
# Out:
# 0.3

# %%
lst = []
for n in 1:N
    push!(lst, calc(N, n, ϵ))
end

# %%
plot(1:N, lst)
